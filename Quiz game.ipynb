# %%
import random

# Define a list of quiz questions and answers.
quiz_questions = [
    {
        "question": " If somebody is three sheets to the wind, what is he?",
        "choices": ["A)Drunk", "B)Hungry", "C)Angry ", "D)Silly "],
        "correct_answer": "A"
    },
    {
        "question": "Where about in the body are the semi-circular canals?",
        "choices": ["A)Heart", "B)Throat", "C)Ear", "D)Foot"],
        "correct_answer": "C"
    },
    {
        "question": "Who set out the famous laws of universal gravitation in 1687?",
        "choices": ["A)Isaac Newton", "B)Alexander Fleming", "C)George Eastman", "D)Galileo"],
        "correct_answer": "A"
    }
]

def display_welcome_message():
    print("Welcome to the Quiz Game!")
    print("You will be asked multiple-choice questions. Choose the correct option.")
    print("Let's begin!\n")

def ask_question(question_dict):
    print(question_dict["question"])
    for choice in question_dict["choices"]:
        print(choice)
    user_answer = input("Your answer (A/B/C/D): ").strip().upper()
    return user_answer

def evaluate_answer(question, user_answer):
    correct_answer = question["correct_answer"]
    if user_answer == correct_answer:
        print("Correct!\n")
        return 1
    else:
        print(f"Sorry, the correct answer is {correct_answer}.\n")
        return 0

def main():
    display_welcome_message()
    play_again = True
    total_score = 0

    while play_again:
        random.shuffle(quiz_questions)
        current_score = 0

        for question in quiz_questions:
            user_answer = ask_question(question)
            current_score += evaluate_answer(question, user_answer)

        total_score += current_score
        print(f"Your score for this round: {current_score}/{len(quiz_questions)}")
        
        play_again_input = input("Do you want to play again? (yes/no): ").strip().lower()
        play_again = (play_again_input == "yes")

    print(f"Your final score: {total_score}/{len(quiz_questions) * len(quiz_questions)}")
    print("Thank you for playing!")

if __name__ == "__main__":
    main()
# Out:
# Welcome to the Quiz Game!
# You will be asked multiple-choice questions. Choose the correct option.
# Let's begin!
#
# Where about in the body are the semi-circular canals?
# A)Heart
# B)Throat
# C)Ear
# D)Foot
# Your answer (A/B/C/D): c
# Correct!
#
# Who set out the famous laws of universal gravitation in 1687?
# A)Isaac Newton
# B)Alexander Fleming
# C)George Eastman
# D)Galileo
# Your answer (A/B/C/D): b
# Sorry, the correct answer is A.
#
#  If somebody is three sheets to the wind, what is he?
# A)Drunk
# B)Hungry
# C)Angry
# D)Silly
# Your answer (A/B/C/D): a
# Correct!
#
# Your score for this round: 2/3
# Do you want to play again? (yes/no): n
# Your final score: 2/9
# Thank you for playing!
